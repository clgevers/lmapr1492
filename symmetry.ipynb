# %%
#Package pour créer le CIF
from pymatgen.ext.matproj import MPRester
from pymatgen.io.cif import CifWriter

#Package pour les opérations de symétrie
from pymatgen.core.operations import SymmOp

#Package pour afficher des images
from IPython.display import Image

from IPython.display import Markdown, display
def printmd(string, color=None):
    colorstr = "<span style='color:{}'>{}</span>".format(color, string)
    display(Markdown(colorstr))


with MPRester("ZarSSb6qGcklK3b9WT") as m:

    # Pour obtenir la structure du materiau
    structure = m.get_structure_by_material_id("mp-24199")
    #Création du cif
    w = CifWriter(structure)
    w.write_file('LiHF2_mp-24199_symmetrized')
    
    #Première opération de symétrie: la translation sur un atome d'hydrogène.
    printmd('**Première opération de symétrie: la translation (x-1/3, y+1/3, z+1/3)**', color = "blue")
    Opop1 = SymmOp.from_xyz_string('x-1/3,y+1/3,z+1/3')
    
    #calcul de la matrice de translation
    print('Voici la matrice de translation (x-1/3,y+1/3,z+1/3):')
    print(Opop1.rotation_matrix)
    
    #Calcul de la translation appliqué à l'Hydrogène H1
    print('Cette opération appliquée à l atome d hydrogène H1 en position (0.33, 0.66, 0.17),') 
    print('le translate à la coordonnée suivante:')
    AtomeTranslat = Opop1.operate((0.33, 0.66, 0.17))
    print(AtomeTranslat)
    
    #Afficher l'image pour illuster l'opération de symétrie
    print('L image suivante représente l opération de translation sur l atome d hydrogène H1' )
# Out:
# <span style='color:blue'>**Première opération de symétrie: la translation (x-1/3, y+1/3, z+1/3)**</span>
# Voici la matrice de translation (x-1/3,y+1/3,z+1/3):
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# Cette opération appliquée à l atome d hydrogène H1 en position (0.33, 0.66, 0.17),
# le translate à la coordonnée suivante:
# [-0.00333333  0.99333333  0.50333333]
# L image suivante représente l opération de translation sur l atome d hydrogène H1

# %% [markdown]
# ![Translate_2.jpg](attachment:Translate_2.jpg)

# %%
#Package pour créer le CIF
from pymatgen.ext.matproj import MPRester
from pymatgen.io.cif import CifWriter

#Package pour les opérations de symétrie
from pymatgen.core.operations import SymmOp

#Package pour afficher des images
from IPython.display import Image

from IPython.display import Markdown, display
def printmd(string, color=None):
    colorstr = "<span style='color:{}'>{}</span>".format(color, string)
    display(Markdown(colorstr))


with MPRester("ZarSSb6qGcklK3b9WT") as m:

    # Pour obtenir la structure du materiau
    structure = m.get_structure_by_material_id("mp-24199")
    #Création du cif
    w = CifWriter(structure)
    w.write_file('LiHF2_mp-24199_symmetrized')
    
    #Première opération de symétrie: la translation sur un atome de fluor.
    printmd('**Deuxième opération de symétrie: le plan mirroir (x,x-y,z)**', color = "blue")
    Opop2 = SymmOp.from_xyz_string('x,x-y,z')
    
    #calcul de la matrice de translation
    print('Voici la matrice de l opération de symétrie du plan miroir (x,x-y,z):')
    print(Opop2.rotation_matrix)
    
    #Calcul de la translation appliqué au Fluor F2
    print('Cette opération appliquée à l atome de fluor en position (0.33, 0.67, 1.08),') 
    print('le déplace à la coordonnée suivante:')
    AtomePlanM = Opop2.operate((0.33, 0.67, 1.08))
    print(AtomePlanM)
    
    #Afficher l'image pour illuster l'opération de symétrie
    print('L image suivante représente l opération de translation sur l atome de fluor F2' )
# Out:
# <span style='color:blue'>**Deuxième opération de symétrie: le plan mirroir (x,x-y,z)**</span>
# Voici la matrice de l opération de symétrie du plan miroir (x,x-y,z):
# [[ 1.  0.  0.]
#  [ 1. -1.  0.]
#  [ 0.  0.  1.]]
# Cette opération appliquée à l atome de fluor en position (0.33, 0.67, 1.08),
# le déplace à la coordonnée suivante:
# [ 0.33 -0.34  1.08]
# L image suivante représente l opération de translation sur l atome de fluor F2

# %% [markdown]
# ![Plan_mirroir_1.jpg](attachment:Plan_mirroir_1.jpg)

# %%
#Package pour créer le CIF
from pymatgen.ext.matproj import MPRester
from pymatgen.io.cif import CifWriter

#Package pour les opérations de symétrie
from pymatgen.core.operations import SymmOp

#Package pour afficher des images
from IPython.display import Image

from IPython.display import Markdown, display
def printmd(string, color=None):
    colorstr = "<span style='color:{}'>{}</span>".format(color, string)
    display(Markdown(colorstr))


with MPRester("ZarSSb6qGcklK3b9WT") as m:

    # Pour obtenir la structure du materiau
    structure = m.get_structure_by_material_id("mp-24199")
    #Création du cif
    w = CifWriter(structure)
    w.write_file('LiHF2_mp-24199_symmetrized')
    
    #Troisième opération de symétrie: la translation sur un atome de fluor.
    printmd('**Troisième opération de symétrie: le plan de glissement (-x+y+1/3,y-1/3,z-1/3)**', color = "blue")
    Opop3 = SymmOp.from_xyz_string('-x+y+1/3,y-1/3,z-1/3')
    
    #calcul de la matrice de translation
    print('Voici la matrice de l opération de symétrie du plan miroir (-x+y+1/3,y-1/3,z-1/3):')
    print(Opop3.rotation_matrix)
    
    #Calcul de la translation appliqué au Lithium Li0
    print('Cette opération appliquée à l atome de lithium en position (0, 0, 0),') 
    print('le déplace à la coordonnée suivante:')
    AtomePlanG = Opop3.operate((0.0, 0.0, 0.0))
    print(AtomePlanG)
    
    #Afficher l'image pour illuster l'opération de symétrie
    print('L image suivante représente l opération de translation sur l atome de lithium Li0' )
# Out:
# <span style='color:blue'>**Troisième opération de symétrie: le plan de glissement (-x+y+1/3,y-1/3,z-1/3)**</span>
# Voici la matrice de l opération de symétrie du plan miroir (-x+y+1/3,y-1/3,z-1/3):
# [[-1.  1.  0.]
#  [ 0.  1.  0.]
#  [ 0.  0.  1.]]
# Cette opération appliquée à l atome de lithium en position (0, 0, 0),
# le déplace à la coordonnée suivante:
# [ 0.33333333 -0.33333333 -0.33333333]
# L image suivante représente l opération de translation sur l atome de lithium Li0

# %% [markdown]
# ![Plan_de_glissement.jpg](attachment:Plan_de_glissement.jpg)
